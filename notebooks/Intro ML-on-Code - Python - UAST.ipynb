# %% [markdown]
# # Topics Covered:
#
#  - [Initialize Apache Spark](#Initialize-Apache-Spark)
#  - [Blobs of HEAD for Pyhton and Java](#Blobs-of-HEAD-for-Pyhton-and-Java)
#  - [Read content of the files](#Read-content-of-the-files)
#  - [Extract UASTs](#Extract-UASTs)
#  - [Visualize UASTs](#Visualize-UASTs)
#  - [Manipulate UASTs](#Manipulate UASTs)

# %% [markdown]
# # Initialize Apache Spark

# %%
from sourced.engine import Engine
from pyspark.sql import SparkSession
import pyspark.sql.functions as fn

spark = SparkSession.builder\
  .master("local[*]").appName("workshop 2").getOrCreate()

engine = Engine(spark, "/repositories/siva/latest/", "siva")
print("%d repositories successfully loaded" % (engine.repositories.rdd.countApprox(1000)))
# Out:
# 4 repositories successfully loaded

# %% [markdown]
# # Blobs of HEAD for Pyhton and Java

# %%
repos = engine.repositories

refs = repos\
    .filter(repos.is_fork == False)\
    .references

langs = refs\
    .filter(refs.is_remote == True)\
    .head_ref.commits\
    .tree_entries.blobs\
    .classify_languages()

head_blobs = langs\
    .filter(langs.is_binary == False)\
    .filter(langs.lang.isin(["Python", "Java"]))\
    .cache()

# %%
print("Number of blobs: {}".format(head_blobs.count()))
head_blobs.printSchema()
# Out:
# Number of blobs: 11
# root
#  |-- blob_id: string (nullable = true)
#  |-- commit_hash: string (nullable = true)
#  |-- repository_id: string (nullable = true)
#  |-- reference_name: string (nullable = true)
#  |-- content: binary (nullable = true)
#  |-- is_binary: boolean (nullable = false)
#  |-- path: string (nullable = true)
#  |-- lang: string (nullable = true)

# %% [markdown]
# # Read content of the files

# %%
head_blobs\
    .select("repository_id", "path", \
            fn.translate(fn.decode(fn.substring(head_blobs.content, 0, 37), "UTF-8"), "\r\n", "  ").alias("content"))\
    .show(10, False)
# Out:
# +-------------------------+--------------------------------------------------+-------------------------------------+
# |repository_id            |path                                              |content                              |
# +-------------------------+--------------------------------------------------+-------------------------------------+
# |github.com/src-d/enry    |java/src/main/java/tech/sourced/enry/Enry.java    |package tech.sourced.enry;  import te|
# |github.com/src-d/enry    |java/src/main/java/tech/sourced/enry/GoUtils.java |package tech.sourced.enry;  import co|
# |github.com/src-d/enry    |java/src/main/java/tech/sourced/enry/Guess.java   |package tech.sourced.enry;  /**  * Gu|
# |github.com/src-d/enry    |java/src/test/java/tech/sourced/enry/EnryTest.java|package tech.sourced.enry;  import or|
# |github.com/src-d/hercules|contrib/_plugin_example/plot_churn.py             |import argparse from datetime import |
# |github.com/src-d/hercules|fix_yaml_unicode.py                               |import yaml import sys  yaml_invalid |
# |github.com/src-d/hercules|labours.py                                        |#!/usr/bin/env python3 import argpars|
# |github.com/src-d/hercules|pb/__init__.py                                    |                                     |
# |github.com/src-d/hercules|swivel.py                                         |#!/usr/bin/env python3 # # Copyright |
# |github.com/src-d/hercules|test_data/1.java                                  |/**  *    Copyright (C) 2012 ZeroTurn|
# +-------------------------+--------------------------------------------------+-------------------------------------+
# only showing top 10 rows

# %% [markdown]
# # Extract UASTs

# %%
uasts = head_blobs\
    .extract_uasts()\
    .cache()

# %%
uasts.printSchema()
# Out:
# root
#  |-- blob_id: string (nullable = true)
#  |-- commit_hash: string (nullable = true)
#  |-- repository_id: string (nullable = true)
#  |-- reference_name: string (nullable = true)
#  |-- content: binary (nullable = true)
#  |-- is_binary: boolean (nullable = false)
#  |-- path: string (nullable = true)
#  |-- lang: string (nullable = true)
#  |-- uast: array (nullable = false)
#  |    |-- element: binary (containsNull = true)

# %%
uasts.select("repository_id", "path", "uast").show(10, False)
# Out:
# +-------------------------+--------------------------------------------------+-------------+
# |repository_id            |path                                              |uast         |
# +-------------------------+--------------------------------------------------+-------------+
# |github.com/src-d/enry    |java/src/main/java/tech/sourced/enry/Enry.java    |[[B@1b1f1a73]|
# |github.com/src-d/enry    |java/src/main/java/tech/sourced/enry/GoUtils.java |[[B@43ab1c46]|
# |github.com/src-d/enry    |java/src/main/java/tech/sourced/enry/Guess.java   |[[B@4240d5bf]|
# |github.com/src-d/enry    |java/src/test/java/tech/sourced/enry/EnryTest.java|[[B@c12084]  |
# |github.com/src-d/hercules|contrib/_plugin_example/plot_churn.py             |[[B@636e7e6d]|
# |github.com/src-d/hercules|fix_yaml_unicode.py                               |[[B@78bc076a]|
# |github.com/src-d/hercules|labours.py                                        |[[B@3c95c8ef]|
# |github.com/src-d/hercules|pb/__init__.py                                    |[]           |
# |github.com/src-d/hercules|swivel.py                                         |[[B@35d91af9]|
# |github.com/src-d/hercules|test_data/1.java                                  |[[B@25d49739]|
# +-------------------------+--------------------------------------------------+-------------+
# only showing top 10 rows

# %% [markdown]
# # Visualize UASTs

# %%
from bblfsh import Node, filter as filter_uast, role_name

# %%
actual_uasts = uasts.select("uast").limit(1).collect()

for x in actual_uasts:
   print(Node.FromString(x.uast[0]))
# Out:
# internal_type: "CompilationUnit"
# children {
#   internal_type: "PackageDeclaration"
#   properties {
#     key: "internalRole"
#     value: "package"
#   }
#   children {
#     internal_type: "QualifiedName"
#     properties {
#       key: "internalRole"
#       value: "name"
#     }
#     children {
#       internal_type: "QualifiedName"
#       properties {
#         key: "internalRole"
#         value: "qualifier"
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "qualifier"
#         }
#         token: "tech"
#         start_position {
#           offset: 8
#           line: 1
#           col: 9
#         }
#         end_position {
#           offset: 12
#           line: 1
#           col: 13
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "sourced"
#         start_position {
#           offset: 13
#           line: 1
#           col: 14
#         }
#         end_position {
#           offset: 20
#           line: 1
#           col: 21
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#       }
#       start_position {
#         offset: 8
#         line: 1
#         col: 9
#       }
#       end_position {
#         offset: 20
#         line: 1
#         col: 21
#       }
#       roles: EXPRESSION
#       roles: IDENTIFIER
#       roles: QUALIFIED
#     }
#     children {
#       internal_type: "SimpleName"
#       properties {
#         key: "internalRole"
#         value: "name"
#       }
#       token: "enry"
#       start_position {
#         offset: 21
#         line: 1
#         col: 22
#       }
#       end_position {
#         offset: 25
#         line: 1
#         col: 26
#       }
#       roles: EXPRESSION
#       roles: IDENTIFIER
#     }
#     start_position {
#       offset: 8
#       line: 1
#       col: 9
#     }
#     end_position {
#       offset: 25
#       line: 1
#       col: 26
#     }
#     roles: EXPRESSION
#     roles: IDENTIFIER
#     roles: QUALIFIED
#   }
#   token: "package"
#   start_position {
#     line: 1
#     col: 1
#   }
#   end_position {
#     offset: 26
#     line: 1
#     col: 27
#   }
#   roles: DECLARATION
#   roles: PACKAGE
# }
# children {
#   internal_type: "ImportDeclaration"
#   properties {
#     key: "internalRole"
#     value: "imports"
#   }
#   properties {
#     key: "onDemand"
#     value: "true"
#   }
#   properties {
#     key: "static"
#     value: "false"
#   }
#   children {
#     internal_type: "QualifiedName"
#     properties {
#       key: "internalRole"
#       value: "name"
#     }
#     children {
#       internal_type: "QualifiedName"
#       properties {
#         key: "internalRole"
#         value: "qualifier"
#       }
#       children {
#         internal_type: "QualifiedName"
#         properties {
#           key: "internalRole"
#           value: "qualifier"
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "qualifier"
#           }
#           token: "tech"
#           start_position {
#             offset: 35
#             line: 3
#             col: 8
#           }
#           end_position {
#             offset: 39
#             line: 3
#             col: 12
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "name"
#           }
#           token: "sourced"
#           start_position {
#             offset: 40
#             line: 3
#             col: 13
#           }
#           end_position {
#             offset: 47
#             line: 3
#             col: 20
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         start_position {
#           offset: 35
#           line: 3
#           col: 8
#         }
#         end_position {
#           offset: 47
#           line: 3
#           col: 20
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#         roles: QUALIFIED
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "enry"
#         start_position {
#           offset: 48
#           line: 3
#           col: 21
#         }
#         end_position {
#           offset: 52
#           line: 3
#           col: 25
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#       }
#       start_position {
#         offset: 35
#         line: 3
#         col: 8
#       }
#       end_position {
#         offset: 52
#         line: 3
#         col: 25
#       }
#       roles: EXPRESSION
#       roles: IDENTIFIER
#       roles: QUALIFIED
#     }
#     children {
#       internal_type: "SimpleName"
#       properties {
#         key: "internalRole"
#         value: "name"
#       }
#       token: "nativelib"
#       start_position {
#         offset: 53
#         line: 3
#         col: 26
#       }
#       end_position {
#         offset: 62
#         line: 3
#         col: 35
#       }
#       roles: EXPRESSION
#       roles: IDENTIFIER
#     }
#     start_position {
#       offset: 35
#       line: 3
#       col: 8
#     }
#     end_position {
#       offset: 62
#       line: 3
#       col: 35
#     }
#     roles: EXPRESSION
#     roles: IDENTIFIER
#     roles: QUALIFIED
#     roles: PATHNAME
#     roles: IMPORT
#   }
#   start_position {
#     offset: 28
#     line: 3
#     col: 1
#   }
#   end_position {
#     offset: 65
#     line: 3
#     col: 38
#   }
#   roles: DECLARATION
#   roles: IMPORT
# }
# children {
#   internal_type: "ImportDeclaration"
#   properties {
#     key: "internalRole"
#     value: "imports"
#   }
#   properties {
#     key: "onDemand"
#     value: "true"
#   }
#   properties {
#     key: "static"
#     value: "true"
#   }
#   children {
#     internal_type: "QualifiedName"
#     properties {
#       key: "internalRole"
#       value: "name"
#     }
#     children {
#       internal_type: "QualifiedName"
#       properties {
#         key: "internalRole"
#         value: "qualifier"
#       }
#       children {
#         internal_type: "QualifiedName"
#         properties {
#           key: "internalRole"
#           value: "qualifier"
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "qualifier"
#           }
#           token: "tech"
#           start_position {
#             offset: 81
#             line: 5
#             col: 15
#           }
#           end_position {
#             offset: 85
#             line: 5
#             col: 19
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "name"
#           }
#           token: "sourced"
#           start_position {
#             offset: 86
#             line: 5
#             col: 20
#           }
#           end_position {
#             offset: 93
#             line: 5
#             col: 27
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         start_position {
#           offset: 81
#           line: 5
#           col: 15
#         }
#         end_position {
#           offset: 93
#           line: 5
#           col: 27
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#         roles: QUALIFIED
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "enry"
#         start_position {
#           offset: 94
#           line: 5
#           col: 28
#         }
#         end_position {
#           offset: 98
#           line: 5
#           col: 32
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#       }
#       start_position {
#         offset: 81
#         line: 5
#         col: 15
#       }
#       end_position {
#         offset: 98
#         line: 5
#         col: 32
#       }
#       roles: EXPRESSION
#       roles: IDENTIFIER
#       roles: QUALIFIED
#     }
#     children {
#       internal_type: "SimpleName"
#       properties {
#         key: "internalRole"
#         value: "name"
#       }
#       token: "GoUtils"
#       start_position {
#         offset: 99
#         line: 5
#         col: 33
#       }
#       end_position {
#         offset: 106
#         line: 5
#         col: 40
#       }
#       roles: EXPRESSION
#       roles: IDENTIFIER
#     }
#     start_position {
#       offset: 81
#       line: 5
#       col: 15
#     }
#     end_position {
#       offset: 106
#       line: 5
#       col: 40
#     }
#     roles: EXPRESSION
#     roles: IDENTIFIER
#     roles: QUALIFIED
#     roles: PATHNAME
#     roles: IMPORT
#   }
#   start_position {
#     offset: 67
#     line: 5
#     col: 1
#   }
#   end_position {
#     offset: 109
#     line: 5
#     col: 43
#   }
#   roles: DECLARATION
#   roles: IMPORT
# }
# children {
#   internal_type: "TypeDeclaration"
#   properties {
#     key: "interface"
#     value: "false"
#   }
#   properties {
#     key: "internalRole"
#     value: "types"
#   }
#   children {
#     internal_type: "Modifier"
#     properties {
#       key: "internalRole"
#       value: "modifiers"
#     }
#     token: "public"
#     start_position {
#       offset: 111
#       line: 7
#       col: 1
#     }
#     end_position {
#       offset: 117
#       line: 7
#       col: 7
#     }
#     roles: VISIBILITY
#     roles: WORLD
#   }
#   children {
#     internal_type: "SimpleName"
#     properties {
#       key: "internalRole"
#       value: "name"
#     }
#     token: "Enry"
#     start_position {
#       offset: 124
#       line: 7
#       col: 14
#     }
#     end_position {
#       offset: 128
#       line: 7
#       col: 18
#     }
#     roles: EXPRESSION
#     roles: IDENTIFIER
#   }
#   children {
#     internal_type: "FieldDeclaration"
#     properties {
#       key: "internalRole"
#       value: "bodyDeclarations"
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "public"
#       start_position {
#         offset: 135
#         line: 8
#         col: 5
#       }
#       end_position {
#         offset: 141
#         line: 8
#         col: 11
#       }
#       roles: VISIBILITY
#       roles: WORLD
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "static"
#       start_position {
#         offset: 142
#         line: 8
#         col: 12
#       }
#       end_position {
#         offset: 148
#         line: 8
#         col: 18
#       }
#       roles: INCOMPLETE
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "final"
#       start_position {
#         offset: 149
#         line: 8
#         col: 19
#       }
#       end_position {
#         offset: 154
#         line: 8
#         col: 24
#       }
#       roles: INCOMPLETE
#     }
#     children {
#       internal_type: "SimpleType"
#       properties {
#         key: "internalRole"
#         value: "type"
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "Guess"
#         start_position {
#           offset: 155
#           line: 8
#           col: 25
#         }
#         end_position {
#           offset: 160
#           line: 8
#           col: 30
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#       }
#       start_position {
#         offset: 155
#         line: 8
#         col: 25
#       }
#       end_position {
#         offset: 160
#         line: 8
#         col: 30
#       }
#       roles: TYPE
#     }
#     children {
#       internal_type: "VariableDeclarationFragment"
#       properties {
#         key: "internalRole"
#         value: "fragments"
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "unknownLanguage"
#         start_position {
#           offset: 161
#           line: 8
#           col: 31
#         }
#         end_position {
#           offset: 176
#           line: 8
#           col: 46
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#       }
#       children {
#         internal_type: "ClassInstanceCreation"
#         properties {
#           key: "internalRole"
#           value: "initializer"
#         }
#         children {
#           internal_type: "SimpleType"
#           properties {
#             key: "internalRole"
#             value: "type"
#           }
#           children {
#             internal_type: "SimpleName"
#             properties {
#               key: "internalRole"
#               value: "name"
#             }
#             token: "Guess"
#             start_position {
#               offset: 183
#               line: 8
#               col: 53
#             }
#             end_position {
#               offset: 188
#               line: 8
#               col: 58
#             }
#             roles: EXPRESSION
#             roles: IDENTIFIER
#           }
#           start_position {
#             offset: 183
#             line: 8
#             col: 53
#           }
#           end_position {
#             offset: 188
#             line: 8
#             col: 58
#           }
#           roles: CALL
#           roles: CALLEE
#           roles: TYPE
#         }
#         children {
#           internal_type: "StringLiteral"
#           properties {
#             key: "internalRole"
#             value: "arguments"
#           }
#           token: "\"\""
#           start_position {
#             offset: 189
#             line: 8
#             col: 59
#           }
#           end_position {
#             offset: 191
#             line: 8
#             col: 61
#           }
#           roles: EXPRESSION
#           roles: LITERAL
#           roles: STRING
#           roles: CALL
#           roles: ARGUMENT
#           roles: POSITIONAL
#         }
#         children {
#           internal_type: "BooleanLiteral"
#           properties {
#             key: "booleanValue"
#             value: "false"
#           }
#           properties {
#             key: "internalRole"
#             value: "arguments"
#           }
#           start_position {
#             offset: 193
#             line: 8
#             col: 63
#           }
#           end_position {
#             offset: 198
#             line: 8
#             col: 68
#           }
#           roles: EXPRESSION
#           roles: LITERAL
#           roles: BOOLEAN
#           roles: CALL
#           roles: ARGUMENT
#           roles: POSITIONAL
#         }
#         start_position {
#           offset: 179
#           line: 8
#           col: 49
#         }
#         end_position {
#           offset: 199
#           line: 8
#           col: 69
#         }
#         roles: EXPRESSION
#         roles: CALL
#         roles: INSTANCE
#       }
#       start_position {
#         offset: 161
#         line: 8
#         col: 31
#       }
#       end_position {
#         offset: 199
#         line: 8
#         col: 69
#       }
#       roles: DECLARATION
#       roles: VARIABLE
#     }
#     start_position {
#       offset: 135
#       line: 8
#       col: 5
#     }
#     end_position {
#       offset: 200
#       line: 8
#       col: 70
#     }
#     roles: DECLARATION
#     roles: VARIABLE
#   }
#   children {
#     internal_type: "FieldDeclaration"
#     properties {
#       key: "internalRole"
#       value: "bodyDeclarations"
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "private"
#       start_position {
#         offset: 206
#         line: 10
#         col: 5
#       }
#       end_position {
#         offset: 213
#         line: 10
#         col: 12
#       }
#       roles: VISIBILITY
#       roles: INSTANCE
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "static"
#       start_position {
#         offset: 214
#         line: 10
#         col: 13
#       }
#       end_position {
#         offset: 220
#         line: 10
#         col: 19
#       }
#       roles: INCOMPLETE
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "final"
#       start_position {
#         offset: 221
#         line: 10
#         col: 20
#       }
#       end_position {
#         offset: 226
#         line: 10
#         col: 25
#       }
#       roles: INCOMPLETE
#     }
#     children {
#       internal_type: "SimpleType"
#       properties {
#         key: "internalRole"
#         value: "type"
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "EnryLibrary"
#         start_position {
#           offset: 227
#           line: 10
#           col: 26
#         }
#         end_position {
#           offset: 238
#           line: 10
#           col: 37
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#       }
#       start_position {
#         offset: 227
#         line: 10
#         col: 26
#       }
#       end_position {
#         offset: 238
#         line: 10
#         col: 37
#       }
#       roles: TYPE
#     }
#     children {
#       internal_type: "VariableDeclarationFragment"
#       properties {
#         key: "internalRole"
#         value: "fragments"
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "nativeLib"
#         start_position {
#           offset: 239
#           line: 10
#           col: 38
#         }
#         end_position {
#           offset: 248
#           line: 10
#           col: 47
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#       }
#       children {
#         internal_type: "QualifiedName"
#         properties {
#           key: "internalRole"
#           value: "initializer"
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "qualifier"
#           }
#           token: "EnryLibrary"
#           start_position {
#             offset: 251
#             line: 10
#             col: 50
#           }
#           end_position {
#             offset: 262
#             line: 10
#             col: 61
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "name"
#           }
#           token: "INSTANCE"
#           start_position {
#             offset: 263
#             line: 10
#             col: 62
#           }
#           end_position {
#             offset: 271
#             line: 10
#             col: 70
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         start_position {
#           offset: 251
#           line: 10
#           col: 50
#         }
#         end_position {
#           offset: 271
#           line: 10
#           col: 70
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#         roles: QUALIFIED
#       }
#       start_position {
#         offset: 239
#         line: 10
#         col: 38
#       }
#       end_position {
#         offset: 271
#         line: 10
#         col: 70
#       }
#       roles: DECLARATION
#       roles: VARIABLE
#     }
#     start_position {
#       offset: 206
#       line: 10
#       col: 5
#     }
#     end_position {
#       offset: 272
#       line: 10
#       col: 71
#     }
#     roles: DECLARATION
#     roles: VARIABLE
#   }
#   children {
#     internal_type: "MethodDeclaration"
#     properties {
#       key: "constructor"
#       value: "false"
#     }
#     properties {
#       key: "internalRole"
#       value: "bodyDeclarations"
#     }
#     children {
#       internal_type: "Javadoc"
#       properties {
#         key: "internalRole"
#         value: "javadoc"
#       }
#       children {
#         internal_type: "TagElement"
#         properties {
#           key: "internalRole"
#           value: "tags"
#         }
#         children {
#           internal_type: "TextElement"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           properties {
#             key: "text"
#             value: "Returns whether the given language is auxiliary or not."
#           }
#           start_position {
#             offset: 289
#             line: 13
#             col: 8
#           }
#           end_position {
#             offset: 344
#             line: 13
#             col: 63
#           }
#           roles: DOCUMENTATION
#           roles: INCOMPLETE
#         }
#         start_position {
#           offset: 289
#           line: 13
#           col: 8
#         }
#         end_position {
#           offset: 344
#           line: 13
#           col: 63
#         }
#         roles: DOCUMENTATION
#         roles: INCOMPLETE
#       }
#       children {
#         internal_type: "TagElement"
#         properties {
#           key: "internalRole"
#           value: "tags"
#         }
#         properties {
#           key: "tagName"
#           value: "@param"
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           token: "language"
#           start_position {
#             offset: 366
#             line: 15
#             col: 15
#           }
#           end_position {
#             offset: 374
#             line: 15
#             col: 23
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         children {
#           internal_type: "TextElement"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           properties {
#             key: "text"
#             value: " name of the language, e.g. PHP, HTML, ..."
#           }
#           start_position {
#             offset: 374
#             line: 15
#             col: 23
#           }
#           end_position {
#             offset: 416
#             line: 15
#             col: 65
#           }
#           roles: DOCUMENTATION
#           roles: INCOMPLETE
#         }
#         start_position {
#           offset: 359
#           line: 15
#           col: 8
#         }
#         end_position {
#           offset: 416
#           line: 15
#           col: 65
#         }
#         roles: DOCUMENTATION
#         roles: INCOMPLETE
#       }
#       children {
#         internal_type: "TagElement"
#         properties {
#           key: "internalRole"
#           value: "tags"
#         }
#         properties {
#           key: "tagName"
#           value: "@return"
#         }
#         children {
#           internal_type: "TextElement"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           properties {
#             key: "text"
#             value: " if it\'s an auxiliary language"
#           }
#           start_position {
#             offset: 431
#             line: 16
#             col: 15
#           }
#           end_position {
#             offset: 461
#             line: 16
#             col: 45
#           }
#           roles: DOCUMENTATION
#           roles: INCOMPLETE
#         }
#         start_position {
#           offset: 424
#           line: 16
#           col: 8
#         }
#         end_position {
#           offset: 461
#           line: 16
#           col: 45
#         }
#         roles: DOCUMENTATION
#         roles: INCOMPLETE
#       }
#       start_position {
#         offset: 278
#         line: 12
#         col: 5
#       }
#       end_position {
#         offset: 469
#         line: 17
#         col: 8
#       }
#       roles: DOCUMENTATION
#       roles: COMMENT
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "public"
#       start_position {
#         offset: 474
#         line: 18
#         col: 5
#       }
#       end_position {
#         offset: 480
#         line: 18
#         col: 11
#       }
#       roles: VISIBILITY
#       roles: WORLD
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "static"
#       start_position {
#         offset: 481
#         line: 18
#         col: 12
#       }
#       end_position {
#         offset: 487
#         line: 18
#         col: 18
#       }
#       roles: INCOMPLETE
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "synchronized"
#       start_position {
#         offset: 488
#         line: 18
#         col: 19
#       }
#       end_position {
#         offset: 500
#         line: 18
#         col: 31
#       }
#       roles: INCOMPLETE
#     }
#     children {
#       internal_type: "PrimitiveType"
#       properties {
#         key: "internalRole"
#         value: "returnType2"
#       }
#       token: "boolean"
#       start_position {
#         offset: 501
#         line: 18
#         col: 32
#       }
#       end_position {
#         offset: 508
#         line: 18
#         col: 39
#       }
#       roles: TYPE
#       roles: PRIMITIVE
#     }
#     children {
#       internal_type: "SimpleName"
#       properties {
#         key: "internalRole"
#         value: "name"
#       }
#       token: "isAuxiliaryLanguage"
#       start_position {
#         offset: 509
#         line: 18
#         col: 40
#       }
#       end_position {
#         offset: 528
#         line: 18
#         col: 59
#       }
#       roles: EXPRESSION
#       roles: IDENTIFIER
#       roles: FUNCTION
#       roles: NAME
#     }
#     children {
#       internal_type: "SingleVariableDeclaration"
#       properties {
#         key: "internalRole"
#         value: "parameters"
#       }
#       properties {
#         key: "varargs"
#         value: "false"
#       }
#       children {
#         internal_type: "SimpleType"
#         properties {
#           key: "internalRole"
#           value: "type"
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "name"
#           }
#           token: "String"
#           start_position {
#             offset: 529
#             line: 18
#             col: 60
#           }
#           end_position {
#             offset: 535
#             line: 18
#             col: 66
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         start_position {
#           offset: 529
#           line: 18
#           col: 60
#         }
#         end_position {
#           offset: 535
#           line: 18
#           col: 66
#         }
#         roles: TYPE
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "language"
#         start_position {
#           offset: 536
#           line: 18
#           col: 67
#         }
#         end_position {
#           offset: 544
#           line: 18
#           col: 75
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#         roles: FUNCTION
#         roles: NAME
#       }
#       start_position {
#         offset: 529
#         line: 18
#         col: 60
#       }
#       end_position {
#         offset: 544
#         line: 18
#         col: 75
#       }
#       roles: FUNCTION
#       roles: ARGUMENT
#       roles: DECLARATION
#       roles: VARIABLE
#     }
#     children {
#       internal_type: "Block"
#       properties {
#         key: "internalRole"
#         value: "body"
#       }
#       children {
#         internal_type: "ReturnStatement"
#         properties {
#           key: "internalRole"
#           value: "statements"
#         }
#         children {
#           internal_type: "MethodInvocation"
#           properties {
#             key: "internalRole"
#             value: "expression"
#           }
#           children {
#             internal_type: "SimpleName"
#             properties {
#               key: "internalRole"
#               value: "name"
#             }
#             token: "toJavaBool"
#             start_position {
#               offset: 563
#               line: 19
#               col: 16
#             }
#             end_position {
#               offset: 573
#               line: 19
#               col: 26
#             }
#             roles: EXPRESSION
#             roles: IDENTIFIER
#             roles: CALL
#             roles: CALLEE
#           }
#           children {
#             internal_type: "MethodInvocation"
#             properties {
#               key: "internalRole"
#               value: "arguments"
#             }
#             children {
#               internal_type: "SimpleName"
#               properties {
#                 key: "internalRole"
#                 value: "expression"
#               }
#               token: "nativeLib"
#               start_position {
#                 offset: 574
#                 line: 19
#                 col: 27
#               }
#               end_position {
#                 offset: 583
#                 line: 19
#                 col: 36
#               }
#               roles: EXPRESSION
#               roles: IDENTIFIER
#               roles: CALL
#               roles: RECEIVER
#             }
#             children {
#               internal_type: "SimpleName"
#               properties {
#                 key: "internalRole"
#                 value: "name"
#               }
#               token: "IsAuxiliaryLanguage"
#               start_position {
#                 offset: 584
#                 line: 19
#                 col: 37
#               }
#               end_position {
#                 offset: 603
#                 line: 19
#                 col: 56
#               }
#               roles: EXPRESSION
#               roles: IDENTIFIER
#               roles: CALL
#               roles: CALLEE
#             }
#             children {
#               internal_type: "MethodInvocation"
#               properties {
#                 key: "internalRole"
#                 value: "arguments"
#               }
#               children {
#                 internal_type: "SimpleName"
#                 properties {
#                   key: "internalRole"
#                   value: "name"
#                 }
#                 token: "toGoString"
#                 start_position {
#                   offset: 604
#                   line: 19
#                   col: 57
#                 }
#                 end_position {
#                   offset: 614
#                   line: 19
#                   col: 67
#                 }
#                 roles: EXPRESSION
#                 roles: IDENTIFIER
#                 roles: CALL
#                 roles: CALLEE
#               }
#               children {
#                 internal_type: "SimpleName"
#                 properties {
#                   key: "internalRole"
#                   value: "arguments"
#                 }
#                 token: "language"
#                 start_position {
#                   offset: 615
#                   line: 19
#                   col: 68
#                 }
#                 end_position {
#                   offset: 623
#                   line: 19
#                   col: 76
#                 }
#                 roles: EXPRESSION
#                 roles: IDENTIFIER
#                 roles: CALL
#                 roles: ARGUMENT
#                 roles: POSITIONAL
#               }
#               start_position {
#                 offset: 604
#                 line: 19
#                 col: 57
#               }
#               end_position {
#                 offset: 624
#                 line: 19
#                 col: 77
#               }
#               roles: CALL
#               roles: ARGUMENT
#               roles: POSITIONAL
#               roles: EXPRESSION
#             }
#             start_position {
#               offset: 574
#               line: 19
#               col: 27
#             }
#             end_position {
#               offset: 625
#               line: 19
#               col: 78
#             }
#             roles: CALL
#             roles: ARGUMENT
#             roles: POSITIONAL
#             roles: EXPRESSION
#           }
#           start_position {
#             offset: 563
#             line: 19
#             col: 16
#           }
#           end_position {
#             offset: 626
#             line: 19
#             col: 79
#           }
#           roles: EXPRESSION
#           roles: CALL
#         }
#         start_position {
#           offset: 556
#           line: 19
#           col: 9
#         }
#         end_position {
#           offset: 627
#           line: 19
#           col: 80
#         }
#         roles: STATEMENT
#         roles: RETURN
#       }
#       start_position {
#         offset: 546
#         line: 18
#         col: 77
#       }
#       end_position {
#         offset: 633
#         line: 20
#         col: 6
#       }
#       roles: FUNCTION
#       roles: BODY
#       roles: STATEMENT
#       roles: BLOCK
#       roles: SCOPE
#     }
#     start_position {
#       offset: 278
#       line: 12
#       col: 5
#     }
#     end_position {
#       offset: 633
#       line: 20
#       col: 6
#     }
#     roles: VISIBILITY
#     roles: WORLD
#     roles: DECLARATION
#     roles: FUNCTION
#   }
#   children {
#     internal_type: "MethodDeclaration"
#     properties {
#       key: "constructor"
#       value: "false"
#     }
#     properties {
#       key: "internalRole"
#       value: "bodyDeclarations"
#     }
#     children {
#       internal_type: "Javadoc"
#       properties {
#         key: "internalRole"
#         value: "javadoc"
#       }
#       children {
#         internal_type: "TagElement"
#         properties {
#           key: "internalRole"
#           value: "tags"
#         }
#         children {
#           internal_type: "TextElement"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           properties {
#             key: "text"
#             value: "Returns the language of the given file based on the filename and its"
#           }
#           start_position {
#             offset: 650
#             line: 23
#             col: 8
#           }
#           end_position {
#             offset: 718
#             line: 23
#             col: 76
#           }
#           roles: DOCUMENTATION
#           roles: INCOMPLETE
#         }
#         children {
#           internal_type: "TextElement"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           properties {
#             key: "text"
#             value: "contents."
#           }
#           start_position {
#             offset: 726
#             line: 24
#             col: 8
#           }
#           end_position {
#             offset: 735
#             line: 24
#             col: 17
#           }
#           roles: DOCUMENTATION
#           roles: INCOMPLETE
#         }
#         start_position {
#           offset: 650
#           line: 23
#           col: 8
#         }
#         end_position {
#           offset: 735
#           line: 24
#           col: 17
#         }
#         roles: DOCUMENTATION
#         roles: INCOMPLETE
#       }
#       children {
#         internal_type: "TagElement"
#         properties {
#           key: "internalRole"
#           value: "tags"
#         }
#         properties {
#           key: "tagName"
#           value: "@param"
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           token: "filename"
#           start_position {
#             offset: 757
#             line: 26
#             col: 15
#           }
#           end_position {
#             offset: 765
#             line: 26
#             col: 23
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         children {
#           internal_type: "TextElement"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           properties {
#             key: "text"
#             value: " name of the file with the extension"
#           }
#           start_position {
#             offset: 765
#             line: 26
#             col: 23
#           }
#           end_position {
#             offset: 801
#             line: 26
#             col: 59
#           }
#           roles: DOCUMENTATION
#           roles: INCOMPLETE
#         }
#         start_position {
#           offset: 750
#           line: 26
#           col: 8
#         }
#         end_position {
#           offset: 801
#           line: 26
#           col: 59
#         }
#         roles: DOCUMENTATION
#         roles: INCOMPLETE
#       }
#       children {
#         internal_type: "TagElement"
#         properties {
#           key: "internalRole"
#           value: "tags"
#         }
#         properties {
#           key: "tagName"
#           value: "@param"
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           token: "content"
#           start_position {
#             offset: 816
#             line: 27
#             col: 15
#           }
#           end_position {
#             offset: 823
#             line: 27
#             col: 22
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         children {
#           internal_type: "TextElement"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           properties {
#             key: "text"
#             value: "  array of bytes with the contents of the file (the code)"
#           }
#           start_position {
#             offset: 823
#             line: 27
#             col: 22
#           }
#           end_position {
#             offset: 880
#             line: 27
#             col: 79
#           }
#           roles: DOCUMENTATION
#           roles: INCOMPLETE
#         }
#         start_position {
#           offset: 809
#           line: 27
#           col: 8
#         }
#         end_position {
#           offset: 880
#           line: 27
#           col: 79
#         }
#         roles: DOCUMENTATION
#         roles: INCOMPLETE
#       }
#       children {
#         internal_type: "TagElement"
#         properties {
#           key: "internalRole"
#           value: "tags"
#         }
#         properties {
#           key: "tagName"
#           value: "@return"
#         }
#         children {
#           internal_type: "TextElement"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           properties {
#             key: "text"
#             value: " the guessed language"
#           }
#           start_position {
#             offset: 895
#             line: 28
#             col: 15
#           }
#           end_position {
#             offset: 916
#             line: 28
#             col: 36
#           }
#           roles: DOCUMENTATION
#           roles: INCOMPLETE
#         }
#         start_position {
#           offset: 888
#           line: 28
#           col: 8
#         }
#         end_position {
#           offset: 916
#           line: 28
#           col: 36
#         }
#         roles: DOCUMENTATION
#         roles: INCOMPLETE
#       }
#       start_position {
#         offset: 639
#         line: 22
#         col: 5
#       }
#       end_position {
#         offset: 924
#         line: 29
#         col: 8
#       }
#       roles: DOCUMENTATION
#       roles: COMMENT
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "public"
#       start_position {
#         offset: 929
#         line: 30
#         col: 5
#       }
#       end_position {
#         offset: 935
#         line: 30
#         col: 11
#       }
#       roles: VISIBILITY
#       roles: WORLD
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "static"
#       start_position {
#         offset: 936
#         line: 30
#         col: 12
#       }
#       end_position {
#         offset: 942
#         line: 30
#         col: 18
#       }
#       roles: INCOMPLETE
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "synchronized"
#       start_position {
#         offset: 943
#         line: 30
#         col: 19
#       }
#       end_position {
#         offset: 955
#         line: 30
#         col: 31
#       }
#       roles: INCOMPLETE
#     }
#     children {
#       internal_type: "SimpleType"
#       properties {
#         key: "internalRole"
#         value: "returnType2"
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "String"
#         start_position {
#           offset: 956
#           line: 30
#           col: 32
#         }
#         end_position {
#           offset: 962
#           line: 30
#           col: 38
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#       }
#       start_position {
#         offset: 956
#         line: 30
#         col: 32
#       }
#       end_position {
#         offset: 962
#         line: 30
#         col: 38
#       }
#       roles: TYPE
#     }
#     children {
#       internal_type: "SimpleName"
#       properties {
#         key: "internalRole"
#         value: "name"
#       }
#       token: "getLanguage"
#       start_position {
#         offset: 963
#         line: 30
#         col: 39
#       }
#       end_position {
#         offset: 974
#         line: 30
#         col: 50
#       }
#       roles: EXPRESSION
#       roles: IDENTIFIER
#       roles: FUNCTION
#       roles: NAME
#     }
#     children {
#       internal_type: "SingleVariableDeclaration"
#       properties {
#         key: "internalRole"
#         value: "parameters"
#       }
#       properties {
#         key: "varargs"
#         value: "false"
#       }
#       children {
#         internal_type: "SimpleType"
#         properties {
#           key: "internalRole"
#           value: "type"
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "name"
#           }
#           token: "String"
#           start_position {
#             offset: 975
#             line: 30
#             col: 51
#           }
#           end_position {
#             offset: 981
#             line: 30
#             col: 57
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         start_position {
#           offset: 975
#           line: 30
#           col: 51
#         }
#         end_position {
#           offset: 981
#           line: 30
#           col: 57
#         }
#         roles: TYPE
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "filename"
#         start_position {
#           offset: 982
#           line: 30
#           col: 58
#         }
#         end_position {
#           offset: 990
#           line: 30
#           col: 66
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#         roles: FUNCTION
#         roles: NAME
#       }
#       start_position {
#         offset: 975
#         line: 30
#         col: 51
#       }
#       end_position {
#         offset: 990
#         line: 30
#         col: 66
#       }
#       roles: FUNCTION
#       roles: ARGUMENT
#       roles: DECLARATION
#       roles: VARIABLE
#     }
#     children {
#       internal_type: "SingleVariableDeclaration"
#       properties {
#         key: "internalRole"
#         value: "parameters"
#       }
#       properties {
#         key: "varargs"
#         value: "false"
#       }
#       children {
#         internal_type: "ArrayType"
#         properties {
#           key: "internalRole"
#           value: "type"
#         }
#         children {
#           internal_type: "PrimitiveType"
#           properties {
#             key: "internalRole"
#             value: "elementType"
#           }
#           token: "byte"
#           start_position {
#             offset: 992
#             line: 30
#             col: 68
#           }
#           end_position {
#             offset: 996
#             line: 30
#             col: 72
#           }
#           roles: TYPE
#           roles: PRIMITIVE
#         }
#         children {
#           internal_type: "Dimension"
#           properties {
#             key: "internalRole"
#             value: "dimensions"
#           }
#           start_position {
#             offset: 996
#             line: 30
#             col: 72
#           }
#           end_position {
#             offset: 998
#             line: 30
#             col: 74
#           }
#           roles: TYPE
#           roles: INCOMPLETE
#         }
#         start_position {
#           offset: 992
#           line: 30
#           col: 68
#         }
#         end_position {
#           offset: 998
#           line: 30
#           col: 74
#         }
#         roles: TYPE
#         roles: PRIMITIVE
#         roles: LIST
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "content"
#         start_position {
#           offset: 999
#           line: 30
#           col: 75
#         }
#         end_position {
#           offset: 1006
#           line: 30
#           col: 82
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#         roles: FUNCTION
#         roles: NAME
#       }
#       start_position {
#         offset: 992
#         line: 30
#         col: 68
#       }
#       end_position {
#         offset: 1006
#         line: 30
#         col: 82
#       }
#       roles: FUNCTION
#       roles: ARGUMENT
#       roles: DECLARATION
#       roles: VARIABLE
#     }
#     children {
#       internal_type: "Block"
#       properties {
#         key: "internalRole"
#         value: "body"
#       }
#       children {
#         internal_type: "ReturnStatement"
#         properties {
#           key: "internalRole"
#           value: "statements"
#         }
#         children {
#           internal_type: "MethodInvocation"
#           properties {
#             key: "internalRole"
#             value: "expression"
#           }
#           children {
#             internal_type: "SimpleName"
#             properties {
#               key: "internalRole"
#               value: "name"
#             }
#             token: "toJavaString"
#             start_position {
#               offset: 1025
#               line: 31
#               col: 16
#             }
#             end_position {
#               offset: 1037
#               line: 31
#               col: 28
#             }
#             roles: EXPRESSION
#             roles: IDENTIFIER
#             roles: CALL
#             roles: CALLEE
#           }
#           children {
#             internal_type: "MethodInvocation"
#             properties {
#               key: "internalRole"
#               value: "arguments"
#             }
#             children {
#               internal_type: "SimpleName"
#               properties {
#                 key: "internalRole"
#                 value: "expression"
#               }
#               token: "nativeLib"
#               start_position {
#                 offset: 1038
#                 line: 31
#                 col: 29
#               }
#               end_position {
#                 offset: 1047
#                 line: 31
#                 col: 38
#               }
#               roles: EXPRESSION
#               roles: IDENTIFIER
#               roles: CALL
#               roles: RECEIVER
#             }
#             children {
#               internal_type: "SimpleName"
#               properties {
#                 key: "internalRole"
#                 value: "name"
#               }
#               token: "GetLanguage"
#               start_position {
#                 offset: 1048
#                 line: 31
#                 col: 39
#               }
#               end_position {
#                 offset: 1059
#                 line: 31
#                 col: 50
#               }
#               roles: EXPRESSION
#               roles: IDENTIFIER
#               roles: CALL
#               roles: CALLEE
#             }
#             children {
#               internal_type: "MethodInvocation"
#               properties {
#                 key: "internalRole"
#                 value: "arguments"
#               }
#               children {
#                 internal_type: "SimpleName"
#                 properties {
#                   key: "internalRole"
#                   value: "name"
#                 }
#                 token: "toGoString"
#                 start_position {
#                   offset: 1077
#                   line: 32
#                   col: 17
#                 }
#                 end_position {
#                   offset: 1087
#                   line: 32
#                   col: 27
#                 }
#                 roles: EXPRESSION
#                 roles: IDENTIFIER
#                 roles: CALL
#                 roles: CALLEE
#               }
#               children {
#                 internal_type: "SimpleName"
#                 properties {
#                   key: "internalRole"
#                   value: "arguments"
#                 }
#                 token: "filename"
#                 start_position {
#                   offset: 1088
#                   line: 32
#                   col: 28
#                 }
#                 end_position {
#                   offset: 1096
#                   line: 32
#                   col: 36
#                 }
#                 roles: EXPRESSION
#                 roles: IDENTIFIER
# ...
#                 roles: CALL
#                 roles: CALLEE
#               }
#               children {
#                 internal_type: "SimpleName"
#                 properties {
#                   key: "internalRole"
#                   value: "arguments"
#                 }
#                 token: "path"
#                 start_position {
#                   offset: 7928
#                   line: 217
#                   col: 56
#                 }
#                 end_position {
#                   offset: 7932
#                   line: 217
#                   col: 60
#                 }
#                 roles: EXPRESSION
#                 roles: IDENTIFIER
#                 roles: CALL
#                 roles: ARGUMENT
#                 roles: POSITIONAL
#               }
#               start_position {
#                 offset: 7917
#                 line: 217
#                 col: 45
#               }
#               end_position {
#                 offset: 7933
#                 line: 217
#                 col: 61
#               }
#               roles: CALL
#               roles: ARGUMENT
#               roles: POSITIONAL
#               roles: EXPRESSION
#             }
#             start_position {
#               offset: 7899
#               line: 217
#               col: 27
#             }
#             end_position {
#               offset: 7934
#               line: 217
#               col: 62
#             }
#             roles: CALL
#             roles: ARGUMENT
#             roles: POSITIONAL
#             roles: EXPRESSION
#           }
#           start_position {
#             offset: 7888
#             line: 217
#             col: 16
#           }
#           end_position {
#             offset: 7935
#             line: 217
#             col: 63
#           }
#           roles: EXPRESSION
#           roles: CALL
#         }
#         start_position {
#           offset: 7881
#           line: 217
#           col: 9
#         }
#         end_position {
#           offset: 7936
#           line: 217
#           col: 64
#         }
#         roles: STATEMENT
#         roles: RETURN
#       }
#       start_position {
#         offset: 7871
#         line: 216
#         col: 61
#       }
#       end_position {
#         offset: 7942
#         line: 218
#         col: 6
#       }
#       roles: FUNCTION
#       roles: BODY
#       roles: STATEMENT
#       roles: BLOCK
#       roles: SCOPE
#     }
#     start_position {
#       offset: 7659
#       line: 210
#       col: 5
#     }
#     end_position {
#       offset: 7942
#       line: 218
#       col: 6
#     }
#     roles: VISIBILITY
#     roles: WORLD
#     roles: DECLARATION
#     roles: FUNCTION
#   }
#   children {
#     internal_type: "MethodDeclaration"
#     properties {
#       key: "constructor"
#       value: "false"
#     }
#     properties {
#       key: "internalRole"
#       value: "bodyDeclarations"
#     }
#     children {
#       internal_type: "Javadoc"
#       properties {
#         key: "internalRole"
#         value: "javadoc"
#       }
#       children {
#         internal_type: "TagElement"
#         properties {
#           key: "internalRole"
#           value: "tags"
#         }
#         children {
#           internal_type: "TextElement"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           properties {
#             key: "text"
#             value: "Reports whether the given path is a vendor path or not."
#           }
#           start_position {
#             offset: 7959
#             line: 221
#             col: 8
#           }
#           end_position {
#             offset: 8014
#             line: 221
#             col: 63
#           }
#           roles: DOCUMENTATION
#           roles: INCOMPLETE
#         }
#         start_position {
#           offset: 7959
#           line: 221
#           col: 8
#         }
#         end_position {
#           offset: 8014
#           line: 221
#           col: 63
#         }
#         roles: DOCUMENTATION
#         roles: INCOMPLETE
#       }
#       children {
#         internal_type: "TagElement"
#         properties {
#           key: "internalRole"
#           value: "tags"
#         }
#         properties {
#           key: "tagName"
#           value: "@param"
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           token: "path"
#           start_position {
#             offset: 8036
#             line: 223
#             col: 15
#           }
#           end_position {
#             offset: 8040
#             line: 223
#             col: 19
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         children {
#           internal_type: "TextElement"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           properties {
#             key: "text"
#             value: " of the file or directory"
#           }
#           start_position {
#             offset: 8040
#             line: 223
#             col: 19
#           }
#           end_position {
#             offset: 8065
#             line: 223
#             col: 44
#           }
#           roles: DOCUMENTATION
#           roles: INCOMPLETE
#         }
#         start_position {
#           offset: 8029
#           line: 223
#           col: 8
#         }
#         end_position {
#           offset: 8065
#           line: 223
#           col: 44
#         }
#         roles: DOCUMENTATION
#         roles: INCOMPLETE
#       }
#       children {
#         internal_type: "TagElement"
#         properties {
#           key: "internalRole"
#           value: "tags"
#         }
#         properties {
#           key: "tagName"
#           value: "@return"
#         }
#         children {
#           internal_type: "TextElement"
#           properties {
#             key: "internalRole"
#             value: "fragments"
#           }
#           properties {
#             key: "text"
#             value: " whether it\'s vendor or not"
#           }
#           start_position {
#             offset: 8080
#             line: 224
#             col: 15
#           }
#           end_position {
#             offset: 8107
#             line: 224
#             col: 42
#           }
#           roles: DOCUMENTATION
#           roles: INCOMPLETE
#         }
#         start_position {
#           offset: 8073
#           line: 224
#           col: 8
#         }
#         end_position {
#           offset: 8107
#           line: 224
#           col: 42
#         }
#         roles: DOCUMENTATION
#         roles: INCOMPLETE
#       }
#       start_position {
#         offset: 7948
#         line: 220
#         col: 5
#       }
#       end_position {
#         offset: 8115
#         line: 225
#         col: 8
#       }
#       roles: DOCUMENTATION
#       roles: COMMENT
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "public"
#       start_position {
#         offset: 8120
#         line: 226
#         col: 5
#       }
#       end_position {
#         offset: 8126
#         line: 226
#         col: 11
#       }
#       roles: VISIBILITY
#       roles: WORLD
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "static"
#       start_position {
#         offset: 8127
#         line: 226
#         col: 12
#       }
#       end_position {
#         offset: 8133
#         line: 226
#         col: 18
#       }
#       roles: INCOMPLETE
#     }
#     children {
#       internal_type: "Modifier"
#       properties {
#         key: "internalRole"
#         value: "modifiers"
#       }
#       token: "synchronized"
#       start_position {
#         offset: 8134
#         line: 226
#         col: 19
#       }
#       end_position {
#         offset: 8146
#         line: 226
#         col: 31
#       }
#       roles: INCOMPLETE
#     }
#     children {
#       internal_type: "PrimitiveType"
#       properties {
#         key: "internalRole"
#         value: "returnType2"
#       }
#       token: "boolean"
#       start_position {
#         offset: 8147
#         line: 226
#         col: 32
#       }
#       end_position {
#         offset: 8154
#         line: 226
#         col: 39
#       }
#       roles: TYPE
#       roles: PRIMITIVE
#     }
#     children {
#       internal_type: "SimpleName"
#       properties {
#         key: "internalRole"
#         value: "name"
#       }
#       token: "isVendor"
#       start_position {
#         offset: 8155
#         line: 226
#         col: 40
#       }
#       end_position {
#         offset: 8163
#         line: 226
#         col: 48
#       }
#       roles: EXPRESSION
#       roles: IDENTIFIER
#       roles: FUNCTION
#       roles: NAME
#     }
#     children {
#       internal_type: "SingleVariableDeclaration"
#       properties {
#         key: "internalRole"
#         value: "parameters"
#       }
#       properties {
#         key: "varargs"
#         value: "false"
#       }
#       children {
#         internal_type: "SimpleType"
#         properties {
#           key: "internalRole"
#           value: "type"
#         }
#         children {
#           internal_type: "SimpleName"
#           properties {
#             key: "internalRole"
#             value: "name"
#           }
#           token: "String"
#           start_position {
#             offset: 8164
#             line: 226
#             col: 49
#           }
#           end_position {
#             offset: 8170
#             line: 226
#             col: 55
#           }
#           roles: EXPRESSION
#           roles: IDENTIFIER
#         }
#         start_position {
#           offset: 8164
#           line: 226
#           col: 49
#         }
#         end_position {
#           offset: 8170
#           line: 226
#           col: 55
#         }
#         roles: TYPE
#       }
#       children {
#         internal_type: "SimpleName"
#         properties {
#           key: "internalRole"
#           value: "name"
#         }
#         token: "path"
#         start_position {
#           offset: 8171
#           line: 226
#           col: 56
#         }
#         end_position {
#           offset: 8175
#           line: 226
#           col: 60
#         }
#         roles: EXPRESSION
#         roles: IDENTIFIER
#         roles: FUNCTION
#         roles: NAME
#       }
#       start_position {
#         offset: 8164
#         line: 226
#         col: 49
#       }
#       end_position {
#         offset: 8175
#         line: 226
#         col: 60
#       }
#       roles: FUNCTION
#       roles: ARGUMENT
#       roles: DECLARATION
#       roles: VARIABLE
#     }
#     children {
#       internal_type: "Block"
#       properties {
#         key: "internalRole"
#         value: "body"
#       }
#       children {
#         internal_type: "ReturnStatement"
#         properties {
#           key: "internalRole"
#           value: "statements"
#         }
#         children {
#           internal_type: "MethodInvocation"
#           properties {
#             key: "internalRole"
#             value: "expression"
#           }
#           children {
#             internal_type: "SimpleName"
#             properties {
#               key: "internalRole"
#               value: "name"
#             }
#             token: "toJavaBool"
#             start_position {
#               offset: 8194
#               line: 227
#               col: 16
#             }
#             end_position {
#               offset: 8204
#               line: 227
#               col: 26
#             }
#             roles: EXPRESSION
#             roles: IDENTIFIER
#             roles: CALL
#             roles: CALLEE
#           }
#           children {
#             internal_type: "MethodInvocation"
#             properties {
#               key: "internalRole"
#               value: "arguments"
#             }
#             children {
#               internal_type: "SimpleName"
#               properties {
#                 key: "internalRole"
#                 value: "expression"
#               }
#               token: "nativeLib"
#               start_position {
#                 offset: 8205
#                 line: 227
#                 col: 27
#               }
#               end_position {
#                 offset: 8214
#                 line: 227
#                 col: 36
#               }
#               roles: EXPRESSION
#               roles: IDENTIFIER
#               roles: CALL
#               roles: RECEIVER
#             }
#             children {
#               internal_type: "SimpleName"
#               properties {
#                 key: "internalRole"
#                 value: "name"
#               }
#               token: "IsVendor"
#               start_position {
#                 offset: 8215
#                 line: 227
#                 col: 37
#               }
#               end_position {
#                 offset: 8223
#                 line: 227
#                 col: 45
#               }
#               roles: EXPRESSION
#               roles: IDENTIFIER
#               roles: CALL
#               roles: CALLEE
#             }
#             children {
#               internal_type: "MethodInvocation"
#               properties {
#                 key: "internalRole"
#                 value: "arguments"
#               }
#               children {
#                 internal_type: "SimpleName"
#                 properties {
#                   key: "internalRole"
#                   value: "name"
#                 }
#                 token: "toGoString"
#                 start_position {
#                   offset: 8224
#                   line: 227
#                   col: 46
#                 }
#                 end_position {
#                   offset: 8234
#                   line: 227
#                   col: 56
#                 }
#                 roles: EXPRESSION
#                 roles: IDENTIFIER
#                 roles: CALL
#                 roles: CALLEE
#               }
#               children {
#                 internal_type: "SimpleName"
#                 properties {
#                   key: "internalRole"
#                   value: "arguments"
#                 }
#                 token: "path"
#                 start_position {
#                   offset: 8235
#                   line: 227
#                   col: 57
#                 }
#                 end_position {
#                   offset: 8239
#                   line: 227
#                   col: 61
#                 }
#                 roles: EXPRESSION
#                 roles: IDENTIFIER
#                 roles: CALL
#                 roles: ARGUMENT
#                 roles: POSITIONAL
#               }
#               start_position {
#                 offset: 8224
#                 line: 227
#                 col: 46
#               }
#               end_position {
#                 offset: 8240
#                 line: 227
#                 col: 62
#               }
#               roles: CALL
#               roles: ARGUMENT
#               roles: POSITIONAL
#               roles: EXPRESSION
#             }
#             start_position {
#               offset: 8205
#               line: 227
#               col: 27
#             }
#             end_position {
#               offset: 8241
#               line: 227
#               col: 63
#             }
#             roles: CALL
#             roles: ARGUMENT
#             roles: POSITIONAL
#             roles: EXPRESSION
#           }
#           start_position {
#             offset: 8194
#             line: 227
#             col: 16
#           }
#           end_position {
#             offset: 8242
#             line: 227
#             col: 64
#           }
#           roles: EXPRESSION
#           roles: CALL
#         }
#         start_position {
#           offset: 8187
#           line: 227
#           col: 9
#         }
#         end_position {
#           offset: 8243
#           line: 227
#           col: 65
#         }
#         roles: STATEMENT
#         roles: RETURN
#       }
#       start_position {
#         offset: 8177
#         line: 226
#         col: 62
#       }
#       end_position {
#         offset: 8249
#         line: 228
#         col: 6
#       }
#       roles: FUNCTION
#       roles: BODY
#       roles: STATEMENT
#       roles: BLOCK
#       roles: SCOPE
#     }
#     start_position {
#       offset: 7948
#       line: 220
#       col: 5
#     }
#     end_position {
#       offset: 8249
#       line: 228
#       col: 6
#     }
#     roles: VISIBILITY
#     roles: WORLD
#     roles: DECLARATION
#     roles: FUNCTION
#   }
#   start_position {
#     offset: 111
#     line: 7
#     col: 1
#   }
#   end_position {
#     offset: 8252
#     line: 230
#     col: 2
#   }
#   roles: VISIBILITY
#   roles: WORLD
#   roles: DECLARATION
#   roles: TYPE
# }
# start_position {
#   line: 1
#   col: 1
# }
# end_position {
#   offset: 8253
# }
# roles: FILE

# %%
def uast_roles(uast) -> iter:
    stack = [(0, uast)]
    while stack:
        level, node = stack.pop()
        yield level, node
        stack.extend((level+1, c) for c in node.children[::-1])
        
def node2raw(node, internal_type=True):
    token = "|%s|" % node.token[:20].replace("\n", "\\n")
    roles = ", ".join([role_name(k) for k in node.roles])
    internal_role = node.internal_type
    positions = str(node.start_position.line) if node.start_position.line != 0 else ""
    return [positions, token, internal_role, roles] if internal_type else [positions, token, roles]

def rreplace(s, old, new, times):
    li = s.rsplit(old, times)
    return new.join(li)

def print_table(table):
    col_size = [max(len(cell) for cell in table_col) for table_col in zip(*table)]
    for raw in table:
        print("  ".join(cell.ljust(size) for cell, size in zip(raw, col_size)))

def print_uast_structure(uast, internal_type=True):
    if internal_type:
        table = [["#", "Token", "Internal Role", "Roles Tree"], ["", "", "", ""]]
    else:
        table = [["#", "Token", "Roles Tree"], ["", "", ""]]
    old_level = 0
    for level, node in uast_roles(uast):
        raw = node2raw(node, internal_type)
        if level != 0:
            raw[-1] = "┃ " * (level-1) + "┣ " + raw[-1]
        if level < old_level:
            table[-1][-1] = rreplace(table[-1][-1].replace("┣", "┗"), "┃", "┗", old_level-level-1)
            pass
        table.append(raw)
        old_level = level
    table[-1][-1] = table[-1][-1].replace("┣", "┗").replace("┃", "┗")
    print_table(table)
    
#https://gist.github.com/zurk/f13aa816a7c3220cf700c98c72891ec3#file-vis_uast-py

# %%
for x in uasts.select("uast").limit(1).collect():
   print_uast_structure(Node.FromString(x.uast[0]))
# Out:
# #    Token                   Internal Role                 Roles Tree
#
# 1    ||                      CompilationUnit               FILE
# 1    |package|               PackageDeclaration            ┣ DECLARATION, PACKAGE
# 1    ||                      QualifiedName                 ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# 1    ||                      QualifiedName                 ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# 1    |tech|                  SimpleName                    ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 1    |sourced|               SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 1    |enry|                  SimpleName                    ┃ ┗ ┗ EXPRESSION, IDENTIFIER
# 3    ||                      ImportDeclaration             ┣ DECLARATION, IMPORT
# 3    ||                      QualifiedName                 ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED, PATHNAME, IMPORT
# 3    ||                      QualifiedName                 ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# 3    ||                      QualifiedName                 ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# 3    |tech|                  SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 3    |sourced|               SimpleName                    ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 3    |enry|                  SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 3    |nativelib|             SimpleName                    ┃ ┗ ┗ EXPRESSION, IDENTIFIER
# 5    ||                      ImportDeclaration             ┣ DECLARATION, IMPORT
# 5    ||                      QualifiedName                 ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED, PATHNAME, IMPORT
# 5    ||                      QualifiedName                 ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# 5    ||                      QualifiedName                 ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# 5    |tech|                  SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 5    |sourced|               SimpleName                    ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 5    |enry|                  SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 5    |GoUtils|               SimpleName                    ┃ ┗ ┗ EXPRESSION, IDENTIFIER
# 7    ||                      TypeDeclaration               ┣ VISIBILITY, WORLD, DECLARATION, TYPE
# 7    |public|                Modifier                      ┃ ┣ VISIBILITY, WORLD
# 7    |Enry|                  SimpleName                    ┃ ┣ EXPRESSION, IDENTIFIER
# 8    ||                      FieldDeclaration              ┃ ┣ DECLARATION, VARIABLE
# 8    |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 8    |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 8    |final|                 Modifier                      ┃ ┃ ┣ INCOMPLETE
# 8    ||                      SimpleType                    ┃ ┃ ┣ TYPE
# 8    |Guess|                 SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 8    ||                      VariableDeclarationFragment   ┃ ┃ ┣ DECLARATION, VARIABLE
# 8    |unknownLanguage|       SimpleName                    ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 8    ||                      ClassInstanceCreation         ┃ ┃ ┃ ┣ EXPRESSION, CALL, INSTANCE
# 8    ||                      SimpleType                    ┃ ┃ ┃ ┃ ┣ CALL, CALLEE, TYPE
# 8    |Guess|                 SimpleName                    ┃ ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 8    |""|                    StringLiteral                 ┃ ┃ ┃ ┃ ┣ EXPRESSION, LITERAL, STRING, CALL, ARGUMENT, POSITIONAL
# 8    ||                      BooleanLiteral                ┃ ┃ ┗ ┗ ┗ EXPRESSION, LITERAL, BOOLEAN, CALL, ARGUMENT, POSITIONAL
# 10   ||                      FieldDeclaration              ┃ ┣ DECLARATION, VARIABLE
# 10   |private|               Modifier                      ┃ ┃ ┣ VISIBILITY, INSTANCE
# 10   |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 10   |final|                 Modifier                      ┃ ┃ ┣ INCOMPLETE
# 10   ||                      SimpleType                    ┃ ┃ ┣ TYPE
# 10   |EnryLibrary|           SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 10   ||                      VariableDeclarationFragment   ┃ ┃ ┣ DECLARATION, VARIABLE
# 10   |nativeLib|             SimpleName                    ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 10   ||                      QualifiedName                 ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# 10   |EnryLibrary|           SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 10   |INSTANCE|              SimpleName                    ┃ ┃ ┗ ┗ ┗ EXPRESSION, IDENTIFIER
# 12   ||                      MethodDeclaration             ┃ ┣ VISIBILITY, WORLD, DECLARATION, FUNCTION
# 12   ||                      Javadoc                       ┃ ┃ ┣ DOCUMENTATION, COMMENT
# 13   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 13   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 15   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 15   |language|              SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 15   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 16   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 16   ||                      TextElement                   ┃ ┃ ┃ ┗ ┗ DOCUMENTATION, INCOMPLETE
# 18   |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 18   |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 18   |synchronized|          Modifier                      ┃ ┃ ┣ INCOMPLETE
# 18   |boolean|               PrimitiveType                 ┃ ┃ ┣ TYPE, PRIMITIVE
# 18   |isAuxiliaryLanguage|   SimpleName                    ┃ ┃ ┣ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 18   ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 18   ||                      SimpleType                    ┃ ┃ ┃ ┣ TYPE
# 18   |String|                SimpleName                    ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 18   |language|              SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 18   ||                      Block                         ┃ ┃ ┣ FUNCTION, BODY, STATEMENT, BLOCK, SCOPE
# 19   ||                      ReturnStatement               ┃ ┃ ┃ ┣ STATEMENT, RETURN
# 19   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL
# 19   |toJavaBool|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 19   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 19   |nativeLib|             SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, RECEIVER
# 19   |IsAuxiliaryLanguage|   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 19   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 19   |toGoString|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 19   |language|              SimpleName                    ┃ ┃ ┗ ┗ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 22   ||                      MethodDeclaration             ┃ ┣ VISIBILITY, WORLD, DECLARATION, FUNCTION
# 22   ||                      Javadoc                       ┃ ┃ ┣ DOCUMENTATION, COMMENT
# 23   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 23   ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 24   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 26   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 26   |filename|              SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 26   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 27   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 27   |content|               SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 27   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 28   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 28   ||                      TextElement                   ┃ ┃ ┃ ┗ ┗ DOCUMENTATION, INCOMPLETE
# 30   |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 30   |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 30   |synchronized|          Modifier                      ┃ ┃ ┣ INCOMPLETE
# 30   ||                      SimpleType                    ┃ ┃ ┣ TYPE
# 30   |String|                SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 30   |getLanguage|           SimpleName                    ┃ ┃ ┣ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 30   ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 30   ||                      SimpleType                    ┃ ┃ ┃ ┣ TYPE
# 30   |String|                SimpleName                    ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 30   |filename|              SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 30   ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 30   ||                      ArrayType                     ┃ ┃ ┃ ┣ TYPE, PRIMITIVE, LIST
# 30   |byte|                  PrimitiveType                 ┃ ┃ ┃ ┃ ┣ TYPE, PRIMITIVE
# 30   ||                      Dimension                     ┃ ┃ ┃ ┃ ┗ TYPE, INCOMPLETE
# 30   |content|               SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 30   ||                      Block                         ┃ ┃ ┣ FUNCTION, BODY, STATEMENT, BLOCK, SCOPE
# 31   ||                      ReturnStatement               ┃ ┃ ┃ ┣ STATEMENT, RETURN
# 31   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL
# 31   |toJavaString|          SimpleName                    ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 31   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 31   |nativeLib|             SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, RECEIVER
# 31   |GetLanguage|           SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 32   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 32   |toGoString|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 32   |filename|              SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 33   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 33   |toGoByteSlice|         SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 33   |content|               SimpleName                    ┃ ┃ ┗ ┗ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 37   ||                      MethodDeclaration             ┃ ┣ VISIBILITY, WORLD, DECLARATION, FUNCTION
# 37   ||                      Javadoc                       ┃ ┃ ┣ DOCUMENTATION, COMMENT
# 38   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 38   ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 39   ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 40   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 42   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 42   |filename|              SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 42   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 43   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 43   |content|               SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 43   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 44   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 44   ||                      TextElement                   ┃ ┃ ┃ ┗ ┗ DOCUMENTATION, INCOMPLETE
# 46   |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 46   |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 46   |synchronized|          Modifier                      ┃ ┃ ┣ INCOMPLETE
# 46   ||                      SimpleType                    ┃ ┃ ┣ TYPE
# 46   |Guess|                 SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 46   |getLanguageByContent|  SimpleName                    ┃ ┃ ┣ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 46   ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 46   ||                      SimpleType                    ┃ ┃ ┃ ┣ TYPE
# 46   |String|                SimpleName                    ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 46   |filename|              SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 46   ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 46   ||                      ArrayType                     ┃ ┃ ┃ ┣ TYPE, PRIMITIVE, LIST
# 46   |byte|                  PrimitiveType                 ┃ ┃ ┃ ┃ ┣ TYPE, PRIMITIVE
# 46   ||                      Dimension                     ┃ ┃ ┃ ┃ ┗ TYPE, INCOMPLETE
# 46   |content|               SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 46   ||                      Block                         ┃ ┃ ┣ FUNCTION, BODY, STATEMENT, BLOCK, SCOPE
# 47   ||                      VariableDeclarationStatement  ┃ ┃ ┃ ┣ STATEMENT, DECLARATION, VARIABLE
# 47   ||                      SimpleType                    ┃ ┃ ┃ ┃ ┣ TYPE
# 47   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# 47   |GetLanguageByContent|  SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 47   |ByValue|               SimpleName                    ┃ ┃ ┃ ┃ ┃ ┗ ┗ EXPRESSION, IDENTIFIER
# 47   ||                      VariableDeclarationFragment   ┃ ┃ ┃ ┃ ┣ DECLARATION, VARIABLE
# 47   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 47   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL
# 47   |nativeLib|             SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, RECEIVER
# 47   |GetLanguageByContent|  SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 48   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 48   |toGoString|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 48   |filename|              SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 49   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 49   |toGoByteSlice|         SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 49   |content|               SimpleName                    ┃ ┃ ┃ ┃ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 51   ||                      ReturnStatement               ┃ ┃ ┃ ┣ STATEMENT, RETURN
# 51   ||                      ClassInstanceCreation         ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL, INSTANCE
# 51   ||                      SimpleType                    ┃ ┃ ┃ ┃ ┃ ┣ CALL, CALLEE, TYPE
# 51   |Guess|                 SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 51   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 51   |toJavaString|          SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 51   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED, CALL, ARGUMENT, POSITIONAL
# 51   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 51   |r0|                    SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┗ ┗ EXPRESSION, IDENTIFIER
# 51   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 51   |toJavaBool|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 51   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED, CALL, ARGUMENT, POSITIONAL
# 51   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 51   |r1|                    SimpleName                    ┃ ┃ ┗ ┗ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER
# 54   ||                      MethodDeclaration             ┃ ┣ VISIBILITY, WORLD, DECLARATION, FUNCTION
# 54   ||                      Javadoc                       ┃ ┃ ┣ DOCUMENTATION, COMMENT
# 55   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 55   ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 56   ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 57   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 59   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 59   |content|               SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 59   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 60   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 60   ||                      TextElement                   ┃ ┃ ┃ ┗ ┗ DOCUMENTATION, INCOMPLETE
# 62   |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 62   |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 62   |synchronized|          Modifier                      ┃ ┃ ┣ INCOMPLETE
# 62   ||                      SimpleType                    ┃ ┃ ┣ TYPE
# 62   |Guess|                 SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 62   |getLanguageByEmacsMo|  SimpleName                    ┃ ┃ ┣ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 62   ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 62   ||                      ArrayType                     ┃ ┃ ┃ ┣ TYPE, PRIMITIVE, LIST
# 62   |byte|                  PrimitiveType                 ┃ ┃ ┃ ┃ ┣ TYPE, PRIMITIVE
# 62   ||                      Dimension                     ┃ ┃ ┃ ┃ ┗ TYPE, INCOMPLETE
# 62   |content|               SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 62   ||                      Block                         ┃ ┃ ┣ FUNCTION, BODY, STATEMENT, BLOCK, SCOPE
# 63   ||                      VariableDeclarationStatement  ┃ ┃ ┃ ┣ STATEMENT, DECLARATION, VARIABLE
# 63   ||                      SimpleType                    ┃ ┃ ┃ ┃ ┣ TYPE
# 63   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# 63   |GetLanguageByEmacsMo|  SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 63   |ByValue|               SimpleName                    ┃ ┃ ┃ ┃ ┃ ┗ ┗ EXPRESSION, IDENTIFIER
# 63   ||                      VariableDeclarationFragment   ┃ ┃ ┃ ┃ ┣ DECLARATION, VARIABLE
# 63   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 63   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL
# 63   |nativeLib|             SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, RECEIVER
# 63   |GetLanguageByEmacsMo|  SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 63   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 63   |toGoByteSlice|         SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 63   |content|               SimpleName                    ┃ ┃ ┃ ┃ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 64   ||                      ReturnStatement               ┃ ┃ ┃ ┣ STATEMENT, RETURN
# 64   ||                      ClassInstanceCreation         ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL, INSTANCE
# 64   ||                      SimpleType                    ┃ ┃ ┃ ┃ ┃ ┣ CALL, CALLEE, TYPE
# 64   |Guess|                 SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 64   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 64   |toJavaString|          SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 64   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED, CALL, ARGUMENT, POSITIONAL
# 64   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 64   |r0|                    SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┗ ┗ EXPRESSION, IDENTIFIER
# 64   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 64   |toJavaBool|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 64   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED, CALL, ARGUMENT, POSITIONAL
# 64   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 64   |r1|                    SimpleName                    ┃ ┃ ┗ ┗ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER
# 67   ||                      MethodDeclaration             ┃ ┣ VISIBILITY, WORLD, DECLARATION, FUNCTION
# 67   ||                      Javadoc                       ┃ ┃ ┣ DOCUMENTATION, COMMENT
# 68   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 68   ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 69   ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 70   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 72   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 72   |filename|              SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 72   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 73   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 73   ||                      TextElement                   ┃ ┃ ┃ ┗ ┗ DOCUMENTATION, INCOMPLETE
# 75   |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 75   |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 75   |synchronized|          Modifier                      ┃ ┃ ┣ INCOMPLETE
# 75   ||                      SimpleType                    ┃ ┃ ┣ TYPE
# 75   |Guess|                 SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 75   |getLanguageByExtensi|  SimpleName                    ┃ ┃ ┣ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 75   ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 75   ||                      SimpleType                    ┃ ┃ ┃ ┣ TYPE
# 75   |String|                SimpleName                    ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 75   |filename|              SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 75   ||                      Block                         ┃ ┃ ┣ FUNCTION, BODY, STATEMENT, BLOCK, SCOPE
# 76   ||                      VariableDeclarationStatement  ┃ ┃ ┃ ┣ STATEMENT, DECLARATION, VARIABLE
# 76   ||                      SimpleType                    ┃ ┃ ┃ ┃ ┣ TYPE
# 76   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# 76   |GetLanguageByExtensi|  SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 76   |ByValue|               SimpleName                    ┃ ┃ ┃ ┃ ┃ ┗ ┗ EXPRESSION, IDENTIFIER
# 76   ||                      VariableDeclarationFragment   ┃ ┃ ┃ ┃ ┣ DECLARATION, VARIABLE
# 76   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 76   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL
# 76   |nativeLib|             SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, RECEIVER
# 76   |GetLanguageByExtensi|  SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 76   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 76   |toGoString|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 76   |filename|              SimpleName                    ┃ ┃ ┃ ┃ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 77   ||                      ReturnStatement               ┃ ┃ ┃ ┣ STATEMENT, RETURN
# 77   ||                      ClassInstanceCreation         ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL, INSTANCE
# 77   ||                      SimpleType                    ┃ ┃ ┃ ┃ ┃ ┣ CALL, CALLEE, TYPE
# 77   |Guess|                 SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 77   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 77   |toJavaString|          SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 77   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED, CALL, ARGUMENT, POSITIONAL
# 77   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 77   |r0|                    SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┗ ┗ EXPRESSION, IDENTIFIER
# 77   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 77   |toJavaBool|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 77   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED, CALL, ARGUMENT, POSITIONAL
# 77   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 77   |r1|                    SimpleName                    ┃ ┃ ┗ ┗ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER
# 80   ||                      MethodDeclaration             ┃ ┣ VISIBILITY, WORLD, DECLARATION, FUNCTION
# 80   ||                      Javadoc                       ┃ ┃ ┣ DOCUMENTATION, COMMENT
# 81   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 81   ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 82   ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 83   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 85   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 85   |content|               SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 85   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 86   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 86   ||                      TextElement                   ┃ ┃ ┃ ┗ ┗ DOCUMENTATION, INCOMPLETE
# 88   |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 88   |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 88   |synchronized|          Modifier                      ┃ ┃ ┣ INCOMPLETE
# 88   ||                      SimpleType                    ┃ ┃ ┣ TYPE
# 88   |Guess|                 SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 88   |getLanguageByShebang|  SimpleName                    ┃ ┃ ┣ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 88   ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 88   ||                      ArrayType                     ┃ ┃ ┃ ┣ TYPE, PRIMITIVE, LIST
# 88   |byte|                  PrimitiveType                 ┃ ┃ ┃ ┃ ┣ TYPE, PRIMITIVE
# 88   ||                      Dimension                     ┃ ┃ ┃ ┃ ┗ TYPE, INCOMPLETE
# 88   |content|               SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 88   ||                      Block                         ┃ ┃ ┣ FUNCTION, BODY, STATEMENT, BLOCK, SCOPE
# 89   ||                      VariableDeclarationStatement  ┃ ┃ ┃ ┣ STATEMENT, DECLARATION, VARIABLE
# 89   ||                      SimpleType                    ┃ ┃ ┃ ┃ ┣ TYPE
# 89   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# 89   |GetLanguageByShebang|  SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 89   |ByValue|               SimpleName                    ┃ ┃ ┃ ┃ ┃ ┗ ┗ EXPRESSION, IDENTIFIER
# 89   ||                      VariableDeclarationFragment   ┃ ┃ ┃ ┃ ┣ DECLARATION, VARIABLE
# 89   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 89   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL
# 89   |nativeLib|             SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, RECEIVER
# 89   |GetLanguageByShebang|  SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 89   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 89   |toGoByteSlice|         SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 89   |content|               SimpleName                    ┃ ┃ ┃ ┃ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 90   ||                      ReturnStatement               ┃ ┃ ┃ ┣ STATEMENT, RETURN
# 90   ||                      ClassInstanceCreation         ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL, INSTANCE
# 90   ||                      SimpleType                    ┃ ┃ ┃ ┃ ┃ ┣ CALL, CALLEE, TYPE
# 90   |Guess|                 SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 90   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 90   |toJavaString|          SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 90   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED, CALL, ARGUMENT, POSITIONAL
# 90   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 90   |r0|                    SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┗ ┗ EXPRESSION, IDENTIFIER
# 90   ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 90   |toJavaBool|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 90   ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED, CALL, ARGUMENT, POSITIONAL
# 90   |res|                   SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 90   |r1|                    SimpleName                    ┃ ┃ ┗ ┗ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER
# 93   ||                      MethodDeclaration             ┃ ┣ VISIBILITY, WORLD, DECLARATION, FUNCTION
# 93   ||                      Javadoc                       ┃ ┃ ┣ DOCUMENTATION, COMMENT
# 94   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 94   ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 95   ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 96   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 98   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 98   |filename|              SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 98   ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 99   ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 99   ||                      TextElement                   ┃ ┃ ┃ ┗ ┗ DOCUMENTATION, INCOMPLETE
# 101  |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 101  |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 101  |synchronized|          Modifier                      ┃ ┃ ┣ INCOMPLETE
# 101  ||                      SimpleType                    ┃ ┃ ┣ TYPE
# 101  |Guess|                 SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 101  |getLanguageByFilenam|  SimpleName                    ┃ ┃ ┣ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 101  ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 101  ||                      SimpleType                    ┃ ┃ ┃ ┣ TYPE
# 101  |String|                SimpleName                    ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 101  |filename|              SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 101  ||                      Block                         ┃ ┃ ┣ FUNCTION, BODY, STATEMENT, BLOCK, SCOPE
# 102  ||                      VariableDeclarationStatement  ┃ ┃ ┃ ┣ STATEMENT, DECLARATION, VARIABLE
# 102  ||                      SimpleType                    ┃ ┃ ┃ ┃ ┣ TYPE
# 102  ||                      QualifiedName                 ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, QUALIFIED
# ...
# 185  |IsConfiguration|       SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 185  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 185  |toGoString|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 185  |path|                  SimpleName                    ┃ ┃ ┗ ┗ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 188  ||                      MethodDeclaration             ┃ ┣ VISIBILITY, WORLD, DECLARATION, FUNCTION
# 188  ||                      Javadoc                       ┃ ┃ ┣ DOCUMENTATION, COMMENT
# 189  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 189  ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 191  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 191  |path|                  SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 191  ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 192  ||                      TextElement                   ┃ ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 193  ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 194  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 194  ||                      TextElement                   ┃ ┃ ┃ ┗ ┗ DOCUMENTATION, INCOMPLETE
# 196  |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 196  |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 196  |synchronized|          Modifier                      ┃ ┃ ┣ INCOMPLETE
# 196  |boolean|               PrimitiveType                 ┃ ┃ ┣ TYPE, PRIMITIVE
# 196  |isDocumentation|       SimpleName                    ┃ ┃ ┣ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 196  ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 196  ||                      SimpleType                    ┃ ┃ ┃ ┣ TYPE
# 196  |String|                SimpleName                    ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 196  |path|                  SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 196  ||                      Block                         ┃ ┃ ┣ FUNCTION, BODY, STATEMENT, BLOCK, SCOPE
# 197  ||                      ReturnStatement               ┃ ┃ ┃ ┣ STATEMENT, RETURN
# 197  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL
# 197  |toJavaBool|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 197  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 197  |nativeLib|             SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, RECEIVER
# 197  |IsDocumentation|       SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 197  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 197  |toGoString|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 197  |path|                  SimpleName                    ┃ ┃ ┗ ┗ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 200  ||                      MethodDeclaration             ┃ ┣ VISIBILITY, WORLD, DECLARATION, FUNCTION
# 200  ||                      Javadoc                       ┃ ┃ ┣ DOCUMENTATION, COMMENT
# 201  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 201  ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 203  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 203  |path|                  SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 203  ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 204  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 204  ||                      TextElement                   ┃ ┃ ┃ ┗ ┗ DOCUMENTATION, INCOMPLETE
# 206  |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 206  |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 206  |synchronized|          Modifier                      ┃ ┃ ┣ INCOMPLETE
# 206  |boolean|               PrimitiveType                 ┃ ┃ ┣ TYPE, PRIMITIVE
# 206  |isDotFile|             SimpleName                    ┃ ┃ ┣ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 206  ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 206  ||                      SimpleType                    ┃ ┃ ┃ ┣ TYPE
# 206  |String|                SimpleName                    ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 206  |path|                  SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 206  ||                      Block                         ┃ ┃ ┣ FUNCTION, BODY, STATEMENT, BLOCK, SCOPE
# 207  ||                      ReturnStatement               ┃ ┃ ┃ ┣ STATEMENT, RETURN
# 207  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL
# 207  |toJavaBool|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 207  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 207  |nativeLib|             SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, RECEIVER
# 207  |IsDotFile|             SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 207  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 207  |toGoString|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 207  |path|                  SimpleName                    ┃ ┃ ┗ ┗ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 210  ||                      MethodDeclaration             ┃ ┣ VISIBILITY, WORLD, DECLARATION, FUNCTION
# 210  ||                      Javadoc                       ┃ ┃ ┣ DOCUMENTATION, COMMENT
# 211  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 211  ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 213  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 213  |path|                  SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 213  ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 214  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 214  ||                      TextElement                   ┃ ┃ ┃ ┗ ┗ DOCUMENTATION, INCOMPLETE
# 216  |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 216  |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 216  |synchronized|          Modifier                      ┃ ┃ ┣ INCOMPLETE
# 216  |boolean|               PrimitiveType                 ┃ ┃ ┣ TYPE, PRIMITIVE
# 216  |isImage|               SimpleName                    ┃ ┃ ┣ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 216  ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 216  ||                      SimpleType                    ┃ ┃ ┃ ┣ TYPE
# 216  |String|                SimpleName                    ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 216  |path|                  SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 216  ||                      Block                         ┃ ┃ ┣ FUNCTION, BODY, STATEMENT, BLOCK, SCOPE
# 217  ||                      ReturnStatement               ┃ ┃ ┃ ┣ STATEMENT, RETURN
# 217  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL
# 217  |toJavaBool|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 217  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 217  |nativeLib|             SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, RECEIVER
# 217  |IsImage|               SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 217  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 217  |toGoString|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 217  |path|                  SimpleName                    ┃ ┃ ┗ ┗ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL
# 220  ||                      MethodDeclaration             ┃ ┣ VISIBILITY, WORLD, DECLARATION, FUNCTION
# 220  ||                      Javadoc                       ┃ ┃ ┣ DOCUMENTATION, COMMENT
# 221  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 221  ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 223  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 223  |path|                  SimpleName                    ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER
# 223  ||                      TextElement                   ┃ ┃ ┃ ┃ ┗ DOCUMENTATION, INCOMPLETE
# 224  ||                      TagElement                    ┃ ┃ ┃ ┣ DOCUMENTATION, INCOMPLETE
# 224  ||                      TextElement                   ┃ ┃ ┃ ┗ ┗ DOCUMENTATION, INCOMPLETE
# 226  |public|                Modifier                      ┃ ┃ ┣ VISIBILITY, WORLD
# 226  |static|                Modifier                      ┃ ┃ ┣ INCOMPLETE
# 226  |synchronized|          Modifier                      ┃ ┃ ┣ INCOMPLETE
# 226  |boolean|               PrimitiveType                 ┃ ┃ ┣ TYPE, PRIMITIVE
# 226  |isVendor|              SimpleName                    ┃ ┃ ┣ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 226  ||                      SingleVariableDeclaration     ┃ ┃ ┣ FUNCTION, ARGUMENT, DECLARATION, VARIABLE
# 226  ||                      SimpleType                    ┃ ┃ ┃ ┣ TYPE
# 226  |String|                SimpleName                    ┃ ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER
# 226  |path|                  SimpleName                    ┃ ┃ ┃ ┗ EXPRESSION, IDENTIFIER, FUNCTION, NAME
# 226  ||                      Block                         ┃ ┃ ┣ FUNCTION, BODY, STATEMENT, BLOCK, SCOPE
# 227  ||                      ReturnStatement               ┃ ┃ ┃ ┣ STATEMENT, RETURN
# 227  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┣ EXPRESSION, CALL
# 227  |toJavaBool|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 227  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 227  |nativeLib|             SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, RECEIVER
# 227  |IsVendor|              SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 227  ||                      MethodInvocation              ┃ ┃ ┃ ┃ ┃ ┃ ┣ CALL, ARGUMENT, POSITIONAL, EXPRESSION
# 227  |toGoString|            SimpleName                    ┃ ┃ ┃ ┃ ┃ ┃ ┃ ┣ EXPRESSION, IDENTIFIER, CALL, CALLEE
# 227  |path|                  SimpleName                    ┗ ┗ ┗ ┗ ┗ ┗ ┗ ┗ EXPRESSION, IDENTIFIER, CALL, ARGUMENT, POSITIONAL

# %% [markdown]
# # Manipulate UASTs

# %%
FUNC_XPATH = "//*[@roleFunction and @roleDeclaration]"
FUNC_NAME_XPATH = "/*[@roleFunction and @roleIdentifier and @roleName] " \
                "| /*/*[@roleFunction and @roleIdentifier and @roleName]"

def extract_functions_from_uast(uast):
    """https://github.com/src-d/ml/blob/24c3d750882fceb819d82aed55115e2d9fe3c348/sourced/ml/transformers/moder.py#L80"""
    allfuncs = list(filter_uast(uast, FUNC_XPATH))
    internal = set()
    for func in allfuncs:
        if id(func) in internal:
            continue
        for sub in filter_uast(func, FUNC_XPATH):
            if sub != func:
                internal.add(id(sub))
    for f in allfuncs:
        if id(f) not in internal:
            name = "+".join(n.token for n in filter_uast(f, FUNC_NAME_XPATH))
            if name:
                yield f, name

# %%
for f in extract_functions_from_uast(Node.FromString(actual_uasts[0].uast[0])):
    a, b = f
    print(b)
# Out:
# isAuxiliaryLanguage
# getLanguage
# getLanguageByContent
# getLanguageByEmacsModeline
# getLanguageByExtension
# getLanguageByShebang
# getLanguageByFilename
# getLanguageByModeline
# getLanguageByVimModeline
# getLanguageExtensions
# getLanguages
# getMimeType
# isBinary
# isConfiguration
# isDocumentation
# isDotFile
# isImage
# isVendor
